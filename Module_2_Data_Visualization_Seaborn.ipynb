# %% [markdown]
# # Module 2 Data Visualization with Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

mtcars = pd.read_csv('data/mtcars.csv',usecols=['car_names', 'mpg','hp','cyl','am'],index_col='car_names')
#mtcars

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
# sns.set_style("whitegrid")
# sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})

plt.scatter(mtcars.mpg, mtcars.hp)
plt.xlabel('mpg')
plt.ylabel('hp')
plt.plot()
# Out:
# []

# %% [markdown]
# ## Visualizing Statistical Relationships Between Quantiative Data

# %% [markdown]
# ## Scatter Plot

# %%
import seaborn as sns
sns.scatterplot(x="mpg", y="hp", data=mtcars)

# %%
sns.relplot(x="mpg", y="hp", data=mtcars)

# %%
sns.relplot(x="mpg", y="hp", data=mtcars, kind = 'line')

# %%
sns.relplot(x="mpg", y="hp", data=mtcars, kind = 'scatter')

# %%
sns.scatterplot(x="mpg", y="hp", size="cyl",data=mtcars);

# %%
sns.relplot(x="mpg", y="hp", size="cyl",sizes=(20, 200), data=mtcars);

# %%
sns.scatterplot(x="mpg", y="hp", hue="cyl", size="cyl",sizes=(20, 200),data=mtcars);

# %%
cmap = sns.cubehelix_palette(dark=.5, light=0.9, as_cmap=True)
sns.relplot(x="mpg", y="hp", hue="cyl", size="cyl",sizes=(20, 200),palette=cmap,data=mtcars);

# %%
sns.relplot(x="mpg", y="hp", hue="cyl", size="cyl",sizes=(20, 200),style='am',
                palette='Set2',data=mtcars);

# %%
cmap = sns.cubehelix_palette(dark=.5, light=0.9, as_cmap=True)
sns.scatterplot(x="mpg", y="hp", hue="cyl", size="cyl",sizes=(20, 200),style='am',data=mtcars);

# %% [markdown]
# ## Ex Scatter Plot

# %%
import pandas as pd

college = pd.read_csv('data/college.csv')
college
# Out:
#           id                                               name  \
# 0     102669                          Alaska Pacific University
# 1     101648                          Marion Military Institute
# 2     100830                    Auburn University at Montgomery
# 3     101879                        University of North Alabama
# 4     100858                                  Auburn University
# 5     100663                University of Alabama at Birmingham
# 6     101480                      Jacksonville State University
# 7     102049                                 Samford University
# 8     101709                           University of Montevallo
# 9     100751                          The University of Alabama
# 10    102261                         Southeastern Bible College
# 11    100706                University of Alabama in Huntsville
# 12    101587                         University of West Alabama
# 13    102094                        University of South Alabama
# 14    102368                                    Troy University
# 15    101435                                 Huntingdon College
# 16    101693                               University of Mobile
# 17    102234                                Spring Hill College
# 18    100937                        Birmingham Southern College
# 19    101912                                 Oakwood University
# 20    101073                          Concordia College Alabama
# 21    100724                           Alabama State University
# 22    102377                                Tuskegee University
# 23    100654                           Alabama A & M University
# 24    102270                                   Stillman College
# 25    107585  University of Arkansas Community College-Morri...
# 26    107983           Southern Arkansas University Main Campus
# 27    106467                           Arkansas Tech University
# 28    107877                           Williams Baptist College
# 29    106458              Arkansas State University-Main Campus
# ...      ...                                                ...
# 1239  238430                        Cardinal Stritch University
# 1240  239512                                  Northland College
# 1241  240107                                 Viterbo University
# 1242  239628                                      Ripon College
# 1243  238458                                 Carroll University
# 1244  239716                              Saint Norbert College
# 1245  238476                                   Carthage College
# 1246  239318                    Milwaukee School of Engineering
# 1247  239105                               Marquette University
# 1248  239390                              Mount Mary University
# 1249  238193                                    Alverno College
# 1250  237136                          Appalachian Bible College
# 1251  237215                            Bluefield State College
# 1252  237330                                 Concord University
# 1253  237312                           University of Charleston
# 1254  237792                                Shepherd University
# 1255  237367                          Fairmont State University
# 1256  237525                                Marshall University
# 1257  237640                             Ohio Valley University
# 1258  237899                     West Virginia State University
# 1259  237358                             Davis & Elkins College
# 1260  237950   West Virginia University Institute of Technology
# 1261  238032                           West Virginia University
# 1262  237932                            West Liberty University
# 1263  237969                     West Virginia Wesleyan College
# 1264  237385                            Glenville State College
# 1265  237118                       Alderson Broaddus University
# 1266  238078                         Wheeling Jesuit University
# 1267  237181                                    Bethany College
# 1268  240727                              University of Wyoming
#
#                city state   region highest_degree  control gender  \
# 0         Anchorage    AK     West       Graduate  Private   CoEd
# 1            Marion    AL    South      Associate   Public   CoEd
# 2        Montgomery    AL    South       Graduate   Public   CoEd
# 3          Florence    AL    South       Graduate   Public   CoEd
# 4            Auburn    AL    South       Graduate   Public   CoEd
# 5        Birmingham    AL    South       Graduate   Public   CoEd
# 6      Jacksonville    AL    South       Graduate   Public   CoEd
# 7        Birmingham    AL    South       Graduate  Private   CoEd
# 8        Montevallo    AL    South       Graduate   Public   CoEd
# 9        Tuscaloosa    AL    South       Graduate   Public   CoEd
# 10       Birmingham    AL    South       Bachelor  Private   CoEd
# 11       Huntsville    AL    South       Graduate   Public   CoEd
# 12       Livingston    AL    South       Graduate   Public   CoEd
# 13           Mobile    AL    South       Graduate   Public   CoEd
# 14             Troy    AL    South       Graduate   Public   CoEd
# 15       Montgomery    AL    South       Bachelor  Private   CoEd
# 16           Mobile    AL    South       Graduate  Private   CoEd
# 17           Mobile    AL    South       Graduate  Private   CoEd
# 18       Birmingham    AL    South       Bachelor  Private   CoEd
# 19       Huntsville    AL    South       Graduate  Private   CoEd
# 20            Selma    AL    South       Bachelor  Private   CoEd
# 21       Montgomery    AL    South       Graduate   Public   CoEd
# 22         Tuskegee    AL    South       Graduate  Private   CoEd
# 23           Normal    AL    South       Graduate   Public   CoEd
# 24       Tuscaloosa    AL    South       Bachelor  Private   CoEd
# 25        Morrilton    AR    South      Associate   Public   CoEd
# 26         Magnolia    AR    South       Graduate   Public   CoEd
# 27     Russellville    AR    South       Graduate   Public   CoEd
# 28     Walnut Ridge    AR    South       Bachelor  Private   CoEd
# 29        Jonesboro    AR    South       Graduate   Public   CoEd
# ...             ...   ...      ...            ...      ...    ...
# 1239      Milwaukee    WI  Midwest       Graduate  Private   CoEd
# 1240        Ashland    WI  Midwest       Bachelor  Private   CoEd
# 1241      La Crosse    WI  Midwest       Graduate  Private   CoEd
# 1242          Ripon    WI  Midwest       Bachelor  Private   CoEd
# 1243       Waukesha    WI  Midwest       Graduate  Private   CoEd
# 1244        De Pere    WI  Midwest       Graduate  Private   CoEd
# 1245        Kenosha    WI  Midwest       Graduate  Private   CoEd
# 1246      Milwaukee    WI  Midwest       Graduate  Private   CoEd
# 1247      Milwaukee    WI  Midwest       Graduate  Private   CoEd
# 1248      Milwaukee    WI  Midwest       Graduate  Private  Women
# 1249      Milwaukee    WI  Midwest       Graduate  Private  Women
# 1250     Mount Hope    WV    South       Graduate  Private   CoEd
# 1251      Bluefield    WV    South       Bachelor   Public   CoEd
# 1252         Athens    WV    South       Graduate   Public   CoEd
# 1253     Charleston    WV    South       Graduate  Private   CoEd
# 1254  Shepherdstown    WV    South       Graduate   Public   CoEd
# 1255       Fairmont    WV    South       Graduate   Public   CoEd
# 1256     Huntington    WV    South       Graduate   Public   CoEd
# 1257         Vienna    WV    South       Graduate  Private   CoEd
# 1258      Institute    WV    South       Graduate   Public   CoEd
# 1259         Elkins    WV    South       Bachelor  Private   CoEd
# 1260     Montgomery    WV    South       Bachelor   Public   CoEd
# 1261     Morgantown    WV    South       Graduate   Public   CoEd
# 1262   West Liberty    WV    South       Graduate   Public   CoEd
# 1263     Buckhannon    WV    South       Graduate  Private   CoEd
# 1264      Glenville    WV    South       Bachelor   Public   CoEd
# 1265       Philippi    WV    South       Graduate  Private   CoEd
# 1266       Wheeling    WV    South       Graduate  Private   CoEd
# 1267        Bethany    WV    South       Graduate  Private   CoEd
# 1268        Laramie    WY     West       Graduate   Public   CoEd
#
#       admission_rate  sat_avg  undergrads  tuition  faculty_salary_avg  \
# 0             0.4207     1054         275    19610                5804
# 1             0.6139     1055         433     8778                5916
# 2             0.8017     1009        4304     9080                7255
# 3             0.6788     1029        5485     7412                7424
# 4             0.8347     1215       20514    10200                9487
# 5             0.8569     1107       11383     7510                9957
# 6             0.8326     1041        7060     7092                6801
# 7             0.5954     1165        3033    27324                8367
# 8             0.7430     1070        2644    10660                7437
# 9             0.5105     1185       29851     9826                9667
# 10            1.0000      930         170    11370                4554
# 11            0.8203     1219        5451     9158                9302
# 12            0.7199      990        1916     8018                6146
# 13            0.8335     1048       11267     7188                7195
# 14            0.4414     1050       15025     7564                6246
# 15            0.5839     1026        1149    24550                5772
# 16            0.5847     1014        1460    19475                4914
# 17            0.5177     1116        1215    32468                6071
# 18            0.5339     1181        1180    31708                7451
# 19            0.4787      928        1878    16720                5147
# 20            0.5328      942         322    10320                5812
# 21            0.5326      851        4811     8720                6609
# 22            0.4922      978        2588    19570                8399
# 23            0.5256      827        4206     9096                6892
# 24            0.5901      811        1056    15865                4597
# 25            0.6181      930        1920     2732                4855
# 26            0.7142      989        2784     7736                6269
# 27            0.8626     1010        8845     5862                6083
# 28            0.7049      983         508    14360                4720
# 29            0.7239     1088        9139     7720                6927
# ...              ...      ...         ...      ...                 ...
# 1239          0.8298     1003        2304    26570                5660
# 1240          0.6343     1085         575    31480                6105
# 1241          0.6914     1089        2019    23790                6224
# 1242          0.6745     1108         820    33482                6636
# 1243          0.8084     1090        2934    28550                6708
# 1244          0.8171     1125        2052    33023                6871
# 1245          0.7165     1104        2835    36570                7889
# 1246          0.6865     1243        2592    35520                8602
# 1247          0.6671     1220        8212    35930                9932
# 1248          0.3527      930         716    25852                5894
# 1249          0.6519      930        1689    24434                5749
# 1250          0.6914     1007         196    13590                3068
# 1251          0.3834      927        1529     5832                6165
# 1252          0.3776      999        2234     6580                6084
# 1253          0.6077      988        1513    23200                6237
# 1254          0.9829      999        3489     6570                6668
# 1255          0.6651      965        3699     6306                6479
# 1256          0.7653     1021        8871     6526                7117
# 1257          0.3235      944         387    19260                5029
# 1258          0.4144      942        2237     6228                6245
# 1259          0.5822      986         839    27492                5444
# 1260          0.6192      983        1115     6048                6634
# 1261          0.8579     1069       21945     6960                9459
# 1262          0.7236      965        2264     6415                6527
# 1263          0.7759     1005        1375    27858                5593
# 1264          0.4656      900        1378     6696                6399
# 1265          0.4258      990        1024    22740                4964
# 1266          0.6263     1032        1131    28030                5917
# 1267          0.6205      906         716    25736                5758
# 1268          0.9766     1118        9910     4646                9124
#
#       loan_default_rate  median_debt         lon        lat
# 0                 0.077      23250.0 -149.900278  61.218056
# 1                 0.136      11500.0  -87.319165  32.632354
# 2                 0.106      21335.0  -86.299969  32.366805
# 3                 0.111      21500.0  -87.677251  34.799810
# 4                 0.045      21831.0  -85.480782  32.609857
# 5                 0.062      21941.5  -86.802490  33.520661
# 6                 0.096      23000.0  -85.761354  33.813713
# 7                 0.007      23000.0  -86.802490  33.520661
# 8                 0.103      23266.0  -86.864156  33.100675
# 9                 0.063      23750.0  -87.569173  33.209841
# 10                0.048      24000.0  -86.802490  33.520661
# 11                0.061      24097.0  -86.586104  34.730369
# 12                0.078      24253.0  -88.187247  32.584302
# 13                0.075      24711.0  -88.039891  30.695366
# 14                0.114      25000.0  -85.969951  31.808768
# 15                0.102      26230.0  -86.299969  32.366805
# 16                0.062      27000.0  -88.039891  30.695366
# 17                0.066      27000.0  -88.039891  30.695366
# 18                0.044      27000.0  -86.802490  33.520661
# 19                0.125      27250.0  -86.586104  34.730369
# 20                0.315      32000.0  -87.021101  32.407359
# 21                0.156      33118.5  -86.299969  32.366805
# 22                0.128      33500.0  -85.707727  32.430237
# 23                0.172      33888.0  -86.572224  34.783841
# 24                0.187      38218.0  -87.569173  33.209841
# 25                0.169       8000.5  -92.744054  35.150917
# 26                0.180      17000.0  -93.239334  33.267072
# 27                0.171      17480.0  -93.133786  35.278417
# 28                0.089      19000.0  -90.955953  36.068403
# 29                0.102      19250.0  -90.704279  35.842297
# ...                 ...          ...         ...        ...
# 1239              0.055      27000.0  -87.906474  43.038902
# 1240              0.063      27000.0  -90.883798  46.592443
# 1241              0.028      27000.0  -91.239581  43.801356
# 1242              0.044      27000.0  -88.835945  43.842205
# 1243              0.036      27000.0  -88.231481  43.011678
# 1244              0.029      27000.0  -88.060381  44.448881
# 1245              0.042      27000.0  -87.821185  42.584742
# 1246              0.031      27000.0  -87.906474  43.038902
# 1247              0.013      27000.0  -87.906474  43.038902
# 1248              0.064      28134.0  -87.906474  43.038902
# 1249              0.078      32606.5  -87.906474  43.038902
# 1250              0.057       9300.0  -81.164268  37.895391
# 1251              0.237      19500.0  -81.222319  37.269840
# 1252              0.176      21200.0  -81.016199  37.422341
# 1253              0.066      21940.0  -81.632623  38.349820
# 1254              0.076      22478.0  -77.804161  39.430100
# 1255              0.142      22529.5  -80.142578  39.485085
# 1256              0.117      22705.0  -82.445154  38.419250
# 1257              0.105      23250.0  -81.548458  39.327019
# 1258              0.166      23250.0  -81.765798  38.383770
# 1259              0.086      23840.5  -79.846735  38.925940
# 1260              0.085      23969.0  -81.328445  38.180383
# 1261              0.085      23969.0  -79.955897  39.629526
# 1262              0.104      24915.0  -80.593685  40.169794
# 1263              0.071      26000.0  -80.232028  38.993987
# 1264              0.230      26000.0  -80.837603  38.934257
# 1265              0.073      27000.0  -80.040358  39.152320
# 1266              0.031      27000.0  -80.720915  40.063962
# 1267              0.171      28549.5  -80.556738  40.205627
# 1268              0.042      18750.0 -105.591101  41.311367
#
# [1269 rows x 17 columns]

# %%
sns.relplot(x='tuition', y='sat_avg', data=college)

# %%
sns.relplot(x='tuition', y='sat_avg', hue='control',alpha=0.5, data=college)

# %%
sns.relplot(x='tuition', y='sat_avg', hue='control',size='undergrads',sizes=(20,200), alpha=0.5, data=college)

# %% [markdown]
# ## Ex Scatter Plot (Optional)

# %%
iris = sns.load_dataset("iris")
ax = sns.scatterplot(x=iris.sepal_length, y=iris.sepal_width,hue=iris.species, style=iris.species)

# %% [markdown]
# ## Categorical Scatter Plot

# %%
sns.catplot(x="cyl", y="mpg", data=mtcars);

# %%
sns.catplot(x="cyl", y="mpg", jitter=False,data=mtcars);

# %%
sns.catplot(x="cyl", y="mpg", hue='am',jitter=False,data=mtcars);

# %%
sns.catplot(x="cyl", y="mpg", jitter=False,data=mtcars.query('am==1'));

# %%
sns.catplot(x="cyl", y="mpg", order=[8,6,4],jitter=False,data=mtcars.query('am==1'));

# %% [markdown]
# ## Visualizing Categorical Data

# %% [markdown]
# ## Bar Plot

# %%
sns.catplot(x="cyl", y="mpg", kind='bar',data=mtcars);

# %%
sns.catplot(x="mpg", y="cyl", orient='h',kind='bar',data=mtcars);

# %%
sns.catplot(x="cyl", y="mpg", kind='bar',hue='am',data=mtcars);

# %%
sns.catplot(y="cyl", x="mpg", orient='h',kind='bar',hue='am',data=mtcars);

# %%
sns.catplot(x="cyl", y='mpg', kind = 'bar',col = 'am',data = mtcars);

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic);

# %%
sns.catplot(x="cyl", kind='count',hue='am',data=mtcars);

# %%
sns.catplot(y="cyl", kind='count',hue='am',data=mtcars);

# %%
sns.catplot(x="cyl", y='mpg', kind='bar',col='am',data=mtcars);

# %% [markdown]
# ## Ex: Bar Plot withh Hue

# %%
sns.catplot(x="region",kind='count',data=college);

# %%
sns.catplot(x="region",kind='count', hue='control',data=college);

# %% [markdown]
# ## Visualizing Statistical Distributions

# %% [markdown]
# ## Histogram

# %%
sns.distplot(mtcars.mpg);

# %%
sns.distplot(mtcars.mpg,kde=False);

# %%
sns.jointplot(x="mpg", y="hp", data=mtcars);

# %% [markdown]
# ## Ex: Histogram

# %%
sns.distplot(college.undergrads,kde=False);

# %% [markdown]
# ## Boxplot

# %%
sns.catplot(x="cyl", y="mpg", kind='box',data=mtcars);

# %%
sns.catplot(x="cyl", y="mpg", kind='box',hue='am',data=mtcars);

# %% [markdown]
# ## Ex: Box Plot

# %%
sns.catplot(data=college, x="control", y="tuition", kind="box");

# %%
iris = sns.load_dataset("iris")
sns.catplot(data=iris, x="species", y="sepal_length", kind="box");

# %% [markdown]
# ## Violin Plot

# %%
sns.catplot(x="cyl", y="mpg", kind='violin',data=mtcars);

# %%
sns.catplot(x="cyl", y="mpg", kind='violin',hue='am',data=mtcars);

# %% [markdown]
# ## Visualizing Correlations

# %% [markdown]
# ## Pair Plot

# %%
sns.jointplot(x="mpg", y="hp", data=mtcars);

# %%
sns.pairplot(mtcars);

# %% [markdown]
# ## Ex Pair Plot

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %% [markdown]
# ## Heatmap

# %%
corr = mtcars.corr()
sns.heatmap(corr)

# %%
corr = iris.corr()
sns.heatmap(corr)

# %% [markdown]
# ## Visualizing Statistical Relationship with Regression

# %% [markdown]
# ## Regression Plot

# %%
sns.regplot(x="mpg", y="hp", data=mtcars);

# %%
sns.lmplot(x="mpg", y="hp", data=mtcars);

# %%
sns.lmplot(x="mpg", y="hp", ci=None, data=mtcars);

# %%
sns.lmplot(x="mpg", y="hp", hue="am", data=mtcars);

# %%
sns.lmplot(x="mpg", y="hp", col="am", data=mtcars);

# %% [markdown]
# ## Time Series

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# 5         s9         18  stim  parietal -0.103513
# 6         s8         18  stim  parietal -0.064408
# 7         s7         18  stim  parietal -0.060526
# 8         s6         18  stim  parietal -0.007029
# 9         s5         18  stim  parietal -0.040557
# 10        s4         18  stim  parietal -0.048812
# 11        s3         18  stim  parietal -0.047148
# 12        s2         18  stim  parietal -0.086623
# 13        s1         18  stim  parietal -0.046659
# 14        s0         18  stim  parietal -0.075570
# 15       s13         17  stim  parietal -0.008265
# 16       s12         17  stim  parietal -0.088512
# 17        s7          9  stim  parietal  0.058897
# 18       s10         17  stim  parietal -0.016847
# 19        s9         17  stim  parietal -0.121574
# 20        s8         17  stim  parietal -0.076287
# 21        s7         17  stim  parietal -0.043812
# 22        s6         17  stim  parietal -0.014746
# 23        s5         17  stim  parietal -0.056682
# 24        s4         17  stim  parietal -0.044582
# 25        s3         17  stim  parietal -0.053514
# 26        s2         17  stim  parietal -0.077292
# 27        s1         17  stim  parietal -0.038021
# 28        s0         17  stim  parietal -0.071300
# 29       s13         16  stim  parietal -0.002856
# ...      ...        ...   ...       ...       ...
# 1034      s5         13   cue   frontal -0.014985
# 1035      s4         13   cue   frontal -0.021514
# 1036      s3         13   cue   frontal -0.047639
# 1037      s2         13   cue   frontal  0.047918
# 1038      s1         13   cue   frontal  0.028379
# 1039      s0         13   cue   frontal -0.021729
# 1040     s13         12   cue   frontal -0.020686
# 1041     s12         12   cue   frontal -0.003034
# 1042     s11         12   cue   frontal  0.055766
# 1043     s10         12   cue   frontal  0.005711
# 1044      s9         12   cue   frontal  0.024292
# 1045      s7         12   cue   frontal -0.014005
# 1046      s2          7   cue   frontal -0.078363
# 1047     s10         10   cue   frontal -0.016124
# 1048      s8         10   cue   frontal -0.015141
# 1049     s10          8   cue   frontal -0.052505
# 1050      s9          8   cue   frontal -0.008729
# 1051      s8          8   cue   frontal  0.007278
# 1052      s7          8   cue   frontal  0.015765
# 1053      s6          8   cue   frontal -0.063961
# 1054      s5          8   cue   frontal -0.028292
# 1055      s4          8   cue   frontal -0.160821
# 1056      s3          8   cue   frontal -0.033848
# 1057      s2          8   cue   frontal -0.069666
# 1058      s1          8   cue   frontal -0.136059
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", ci=None, kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal",col="region", row="event", kind="line", data=fmri);
